# %% [markdown]
# ##Import Libraries, Start Query Engine

# %%
import json
import ast
import pandas as pd
import csv
import requests
import time
import traceback
from sqlalchemy import *
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import datetime
import instaconfig

instagram, database, search_tags = instaconfig.config()

engine = create_engine('mysql://%(user)s:%(pass)s@%(host)s' % database)
engine.execute('use instagram_master')

# %%
q = '''
    SELECT *
    FROM posts
    WHERE searched_tag IN 
    # %s ;
    ''' % ("('" + "','".join(search_tags[:7]) + "')")

print q

df = pd.read_sql_query(q,con = engine)
# Out:
#     SELECT *
#     FROM posts
#     WHERE searched_tag IN
#     ('busk','busker','buskers','busking','streetmusic','streetmusician','streetmusicians') ;

# %%
print len(df)
df.head(1)
# Out:
# 8819
#   searched_tag  created_time                        post_id image_url  \
# 0         busk    1438400810  1041703958383645915_647156236      None
#
#          lat  likes   longitude                             post_url  \
# 0  14.550606    184  121.051199  https://instagram.com/p/504Dsgk1Tb/
#
#                                                 text              user_id  \
# 0  Reposted from @hope_aaa "His voice is just too...  1041703995016696991
#
#    ...   date_month  date_week  date_day day_of_week  media_type  \
# 0  ...            7       None        31           4       video
#
#                                          low_res_url  \
# 0  https://scontent.cdninstagram.com/hphotos-xaf1...
#
#                                        thumbnail_url  \
# 0  https://scontent.cdninstagram.com/hphotos-xaf1...
#
#                                        stand_res_url live_music genre
# 0  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
#
# [1 rows x 22 columns]

# %%
from sklearn.neighbors.kde import KernelDensity
from sklearn.grid_search import GridSearchCV
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-2ccf978fbe4d> in <module>()
#       2 from sklearn.grid_search import GridSearchCV
#       3
# ----> 4 Xtrain = np.vstack((photos.longitude, photos.latitude)).T
#       5 Xtrain *= np.pi/180
#       6 Xtrain
#
# NameError: name 'photos' is not defined

# %% [markdown]
# ## Train Kernel Density Estimator

# %%
Xtrain = np.vstack((df.longitude, df.lat)).T
Xtrain *= np.pi/180

kde = KernelDensity(
        bandwidth=1e-4, 
        kernel='epanechnikov',
        metric='haversine',
        #algorithm='ball_tree',
      )

kde.fit(Xtrain)
# Out:
# KernelDensity(algorithm='auto', atol=0, bandwidth=0.0001, breadth_first=True,
#        kernel='epanechnikov', leaf_size=40, metric='haversine',
#        metric_params=None, rtol=0)

# %% [markdown]
# ## Plot KDE and data points

# %%
n = 1000
X = np.linspace(Xtrain[:,0].min(), Xtrain[:,0].max(), n)
Y = np.linspace(Xtrain[:,1].min(), Xtrain[:,1].max(), n)
X, Y = np.meshgrid(X, Y)
xy = np.vstack((X.flat, Y.flat)).T
logZ = kde.score_samples(xy).reshape(n,n)
Z = np.exp(logZ)

# %config InlineBackend.figure_format='retina'
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 10)

levels = np.linspace(0, Z.max(), 25)
plt.contourf(X, Y, Z, levels=levels, cmap=plt.cm.Reds)
plt.scatter(Xtrain[:,0], Xtrain[:,1], s=1, alpha=0.1)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sf_coord = {
    'ul_lat' : 37.85,
    'ul_long' : -122.35,
    'lr_lat' : 37.7,
    'lr_long' : -122.6
    }

    #if 37.7 <= post['location']['latitude'] <= 37.85 \
    #                    and -122.6 <= post['location']['longitude'] <= -122.35:

# %%
def make_small_map(filter_coord, df):
    sf_df = df[(df.lat <= filter_coord['ul_lat']) & (df.longitude <= filter_coord['ul_long']) & (df.lat >= filter_coord['lr_lat']) & (df.longitude >= filter_coord['lr_long'])]

    Xtrain = np.vstack((sf_df.longitude, sf_df.lat)).T
    Xtrain *= np.pi/180

    kde = KernelDensity(
            bandwidth=1e-4, 
            kernel='epanechnikov',
            metric='haversine',
            #algorithm='ball_tree',
          )

    kde.fit(Xtrain)

    n = 1000
    X = np.linspace(Xtrain[:,0].min(), Xtrain[:,0].max(), n)
    Y = np.linspace(Xtrain[:,1].min(), Xtrain[:,1].max(), n)
    X, Y = np.meshgrid(X, Y)
    xy = np.vstack((X.flat, Y.flat)).T
    logZ = kde.score_samples(xy).reshape(n,n)
    Z = np.exp(logZ)

    pylab.rcParams['figure.figsize'] = (10, 10)

    levels = np.linspace(0, Z.max(), 25)
    plt.contourf(X, Y, Z, levels=levels, cmap=plt.cm.Reds)
    plt.scatter(Xtrain[:,0], Xtrain[:,1], s=1, alpha=0.1)

# %%
make_small_map(sf_coord, df)

# %%
# Pictures binned by day of the week

df.groupby(['day_of_week']).count()['searched_tag'].plot(kind = 'bar')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
from mpl_toolkits.basemap import Basemap

Xdeg, Ydeg = X*180/np.pi, Y*180/np.pi

m = Basemap(projection='cyl', 
            llcrnrlat=Ydeg.min(),
            urcrnrlat=Ydeg.max(), 
            llcrnrlon=Xdeg.min(),
            urcrnrlon=Xdeg.max(), 
            resolution='h')

m.drawmapboundary(fill_color='aqua')
m.drawcoastlines()
#Zmask = maskoceans(Xdeg, Ydeg, Z, resolution='h', grid=1.25)
Zmask = Z

plt.contourf(Xdeg, Ydeg, Zmask, levels=levels, cmap=plt.cm.Reds);

# %% [markdown]
# ## dbscan

# %%
import folium
from sklearn.cluster import DBSCAN
from IPython.display import IFrame
from geopy.distance import EARTH_RADIUS

def make_small_map_dbscan(filter_coord, df):
    filtered_df = df[(df.lat <= filter_coord['ul_lat']) & (df.longitude <= filter_coord['ul_long']) & (df.lat >= filter_coord['lr_lat']) & (df.longitude >= filter_coord['lr_long'])]

    filtered_df
    Xtrain = np.vstack((filtered_df.longitude, filtered_df.lat)).T
    Xtrain *= np.pi/180

    print Xtrain
    n = 1000
    radians_per_meter = 1e-3 * EARTH_RADIUS

    db = DBSCAN(
            eps=50*radians_per_meter,
            min_samples=10,
            metric='haversine',
         )

    db.fit(Xtrain)
    
    n = 100
    X = np.linspace(Xtrain[:,0].min(), Xtrain[:,0].max(), n)
    Y = np.linspace(Xtrain[:,1].min(), Xtrain[:,1].max(), n)
    X, Y = np.meshgrid(X, Y)

    plt.contourf(X, Y, Z, levels=levels, cmap=plt.cm.Reds)
    plt.scatter(
        Xtrain[:,0], 
        Xtrain[:,1], 
        c=db.labels_, 
        s=20,
        lw=0,
        cmap=plt.cm.Greys)

# %%
make_small_map_dbscan(sf_coord, df)
# Out:
# [[-2.13713047  0.65920767]
#  [-2.1364731   0.65988769]
#  [-2.13734755  0.65921316]
#  [-2.13710326  0.65921131]
#  [-2.13664751  0.65908885]
#  [-2.13762594  0.65920601]
#  [-2.13641483  0.65950807]
#  [-2.13713047  0.65920767]
#  [-2.13641483  0.65950807]
#  [-2.13653701  0.6598806 ]
#  [-2.13688917  0.65973478]
#  [-2.13654707  0.65987968]
# 8798  This guy is grooving with his street setup!! #...  1072600772878945949
# 8799  First day aku sampai pulau aku terus menyelam ...  1072927270108450010
# 8800                        nightlights#streetmusicians  1073023150875441931
# 8801  I'll tell you all about it when I see you agai...  1073058196509596034
# 8802  15 dk ayrilamadim baslarindan :) #music #stree...  1073117887846285604
# 8803  Very talented street musicians on Columbia Roa...  1073272997981914077
# 8804  Sunday afternoon in Central Park #CentralPark ...  1073450859798525122
# 8805  Sunday afternoon in Central Park #CentralPark ...  1073450691825038510
# 8806  Wherever I travel around the world, I am natur...  1073259973372946960
# 8807      #drum #alsancak #bravo #ritm #streetmusicians  1073264650553786923
# 8808  One of the many #StreetPerformers and #StreetM...  1073364498886861464
# 8809  #f?ssen #streetphoto #concert #bw #blackandwhi...  1073408553982946387
# 8810  #frenchquarter #bourbon #neworleans #streetmus...  1073629498571536406
# 8811  Music in the square ... Piazza del Popolo, Rav...  1073734097389045106
# 8812  #drummer#blackguys#disable#vocalist#streetmusi...  1073801828233946379
# 8813                              High all day long ???  1073836154350255410
# 8814  #GreekMelodies #StreetMusicians #Rhodos2015 #R...  1073891644455929047
# 8815  Drive-by shot of street band performing. Prett...  1074125456141199186
# 8816  Saavn team member @suhaniarora exploring #jazz...  1074126562120891373
# 8817  ????????? ?? ????#?????? #????????? #?????????...  1074814585894408050
# 8818  Vamos ajudar a galera a comprar um microfone.....  1074917909738303917
#
#       ...   date_month  date_week  date_day day_of_week  media_type  \
# 0     ...            7       None        31           4       video
# 1     ...            8       None         1           5       image
# 2     ...            8       None         1           5       image
# 3     ...            8       None         2           6       image
# 4     ...            8       None         2           6       image
# 5     ...            8       None         3           0       image
# 6     ...            8       None         3           0       video
# 7     ...            8       None         4           1       image
# 8     ...            8       None         5           2       image
# 9     ...            8       None         6           3       image
# 10    ...            8       None         8           5       image
# 11    ...            8       None         9           6       image
# 12    ...            8       None         9           6       image
# 13    ...            8       None         9           6       image
# 14    ...            8       None         9           6       video
# 15    ...            8       None         9           6       image
# 16    ...            8       None        11           1       image
# 17    ...            8       None        11           1       image
# 18    ...            8       None        11           1       image
# 19    ...            8       None        14           4       image
# 20    ...            8       None        14           4       image
# 21    ...            8       None        14           4       image
# 22    ...            8       None        14           4       image
# 23    ...            8       None        14           4       image
# 24    ...            8       None        14           4       video
# 25    ...            8       None        15           5       image
# 26    ...            8       None        15           5       image
# 27    ...            8       None        15           5       image
# 28    ...            8       None        15           5       image
# 29    ...            8       None        15           5       image
# ...   ...          ...        ...       ...         ...         ...
# 8789  ...            9       None        10           3       image
# 8790  ...            9       None        11           4       image
# 8791  ...            9       None        11           4       image
# 8792  ...            9       None        11           4       video
# 8793  ...            9       None        12           5       image
# 8794  ...            9       None        12           5       image
# 8795  ...            9       None        12           5       image
# 8796  ...            9       None        12           5       video
# 8797  ...            9       None        12           5       image
# 8798  ...            9       None        12           5       video
# 8799  ...            9       None        12           5       image
# 8800  ...            9       None        13           6       image
# 8801  ...            9       None        13           6       video
# 8802  ...            9       None        13           6       video
# 8803  ...            9       None        13           6       image
# 8804  ...            9       None        13           6       image
# 8805  ...            9       None        13           6       video
# 6     https://scontent.cdninstagram.com/hphotos-xpa1...
# 7     https://scontent.cdninstagram.com/hphotos-xaf1...
# 8     https://scontent.cdninstagram.com/hphotos-xaf1...
# 9     https://scontent.cdninstagram.com/hphotos-xaf1...
# 10    https://scontent.cdninstagram.com/hphotos-xta1...
# 11    https://scontent.cdninstagram.com/hphotos-xaf1...
# 12    https://scontent.cdninstagram.com/hphotos-xfa1...
# 13    https://scontent.cdninstagram.com/hphotos-xaf1...
# 14    https://scontent.cdninstagram.com/hphotos-xaf1...
# 15    https://scontent.cdninstagram.com/hphotos-xaf1...
# 16    https://scontent.cdninstagram.com/hphotos-xfa1...
# 17    https://scontent.cdninstagram.com/hphotos-xfa1...
# 18    https://scontent.cdninstagram.com/hphotos-xaf1...
# 19    https://scontent.cdninstagram.com/hphotos-xaf1...
# 20    https://scontent.cdninstagram.com/hphotos-xaf1...
# 21    https://scontent.cdninstagram.com/hphotos-xfa1...
# 22    https://scontent.cdninstagram.com/hphotos-xaf1...
# 23    https://scontent.cdninstagram.com/hphotos-xaf1...
# 24    https://scontent.cdninstagram.com/hphotos-xfa1...
# 25    https://scontent.cdninstagram.com/hphotos-xaf1...
# 26    https://scontent.cdninstagram.com/hphotos-xat1...
# 27    https://scontent.cdninstagram.com/hphotos-xaf1...
# 28    https://scontent.cdninstagram.com/hphotos-xaf1...
# 29    https://scontent.cdninstagram.com/hphotos-xfa1...
# ...                                                 ...
# 8789  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8790  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8791  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8792  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8793  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8794  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8795  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8796  https://scontent.cdninstagram.com/hphotos-xfa1...
# 8797  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8798  https://scontent.cdninstagram.com/hphotos-xfa1...
# 8799  https://scontent.cdninstagram.com/hphotos-xfa1...
# 8800  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8801  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8802  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8803  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8804  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8805  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8806  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8807  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8808  https://scontent.cdninstagram.com/hphotos-xfa1...
# 8809  https://scontent.cdninstagram.com/hphotos-xfa1...
# 8810  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8811  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8812  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8813  https://scontent.cdninstagram.com/hphotos-xfp1...
# 8814  https://scontent.cdninstagram.com/hphotos-xap1...
# 8815  https://scontent.cdninstagram.com/hphotos-xat1...
# 8816  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8817  https://scontent.cdninstagram.com/hphotos-xaf1...
# 8818  https://scontent.cdninstagram.com/hphotos-xfa1...
#
#                                           stand_res_url live_music genre
# 0     https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 1     https://scontent.cdninstagram.com/hphotos-xap1...       None  None
# 2     https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 3     https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 4     https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 5     https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 6     https://scontent.cdninstagram.com/hphotos-xpa1...       None  None
# 7     https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8     https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 9     https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 10    https://scontent.cdninstagram.com/hphotos-xta1...       None  None
# 11    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 12    https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 13    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 14    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 15    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 16    https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 17    https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 18    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 19    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 20    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 21    https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 22    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 23    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 24    https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 25    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 26    https://scontent.cdninstagram.com/hphotos-xat1...       None  None
# 27    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 28    https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 29    https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# ...                                                 ...        ...   ...
# 8789  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8790  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8791  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8792  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8793  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8794  https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 8795  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8796  https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 8797  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8798  https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 8799  https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 8800  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8801  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8802  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8803  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8804  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8805  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8806  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8807  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8808  https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 8809  https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
# 8810  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8811  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8812  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8813  https://scontent.cdninstagram.com/hphotos-xfp1...       None  None
# 8814  https://scontent.cdninstagram.com/hphotos-xap1...       None  None
# 8815  https://scontent.cdninstagram.com/hphotos-xat1...       None  None
# 8816  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8817  https://scontent.cdninstagram.com/hphotos-xaf1...       None  None
# 8818  https://scontent.cdninstagram.com/hphotos-xfa1...       None  None
#
# [8819 rows x 22 columns]
